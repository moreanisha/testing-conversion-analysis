# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
ab_data = pd.read_csv("people-100.csv")
print(ab_data.head())
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
# conversions
conv_old = 750
conv_new = 900

# visitors
n_old = 10000
n_new = 10000

# %%
cr_old = conv_old / n_old
cr_new = conv_new / n_new

print("Old Conversion Rate:", cr_old)
print("New Conversion Rate:", cr_new)
# Out:
# Old Conversion Rate: 0.075
# New Conversion Rate: 0.09

# %%
z_score, p_value = proportions_ztest(
    [conv_new, conv_old],
    [n_new, n_old],
    alternative='larger'
)

print("Z-score:", z_score)
print("p-value:", p_value)
# Out:
# Z-score: 3.8551941163203147
# p-value: 5.7818918137101185e-05

# %%
from statsmodels.stats.proportion import proportion_confint

ci_old = proportion_confint(conv_old, n_old)
ci_new = proportion_confint(conv_new, n_new)

print("Control CI:", ci_old)
print("Treatment CI:", ci_new)
# Out:
# Control CI: (0.06983762452270609, 0.0801623754772939)
# Treatment CI: (0.08439094056534566, 0.09560905943465434)

# %%
groups = ['Control', 'Treatment']
rates = [0.075, 0.09]

plt.bar(groups, rates)
plt.ylabel("Conversion Rate")
plt.title("Conversion Rate Comparison")
plt.show()
